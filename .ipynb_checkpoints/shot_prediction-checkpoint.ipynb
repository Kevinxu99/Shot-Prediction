# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Loading the data

# %%
data = pd.read_csv('Data/data.csv')
pd.set_option('display.max_columns', None)
data.shape
# Out:
# (119011, 34)

# %%
data.tail()
# Out:
#          GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 119006  21400175    NOV 21, 2014 - MIL @ TOR        A  L           -42
# 119007  21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 119008  21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 119009  21400744  FEB 05, 2015 - SAC vs. DAL        H  L           -23
# 119010  21400498  JAN 03, 2015 - MIN vs. UTA        H  L           -12
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES  TOUCH_TIME  \
# 119006            3       4       8:55        15.2         0         0.8
# 119007            3       3       1:35         3.3         1         2.4
# 119008            2       2      10:10        24.0         0         0.3
# 119009            9       4       3:21        13.3         5         5.4
# 119010            7       4       0:26         2.6         1         0.7
#
#         SHOT_DIST  PTS_TYPE SHOT_RESULT CLOSEST_DEFENDER  \
# 119006       22.9         3      missed    BRUNO CABOCLO
# 119007        6.7         2        made    JULIUS RANDLE
# 119008        4.1         2        made    JULIUS RANDLE
# 119009       21.9         2      missed       RICKY LEDO
# 119010        4.3         2        made     TOURE' MURRY
#
#         CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  FGM  PTS  \
# 119006                      203998            10.6    0    0
# 119007                      203944             5.3    1    2
# 119008                      203944             3.2    1    2
# 119009                      203495             5.0    0    0
# 119010                      203315             2.8    1    2
#
#                 PLAYER_NAME  PLAYER_ID  PLAYER_HEIGHT  DEFENDER_HEIGHT  \
# 119006         JARED DUDLEY     201162          197.5            202.5
# 119007  KOSTAS PAPANIKOLAOU     203123          200.0            202.5
# 119008        DWIGHT HOWARD       2730          207.5            202.5
# 119009         NIK STAUSKAS     203917          195.0            201.0
# 119010      ANTHONY BENNETT     203461          200.0            192.5
#
#         PLAYER_PTS  PLAYER_FG%  PLAYER_3P%  PLAYER_FT%  PLAYER_AST  \
# 119006         7.2        46.8        38.5        71.6         1.8
# 119007         4.2        35.0        29.2        72.2         2.0
# 119008        15.8        59.3        50.0        52.8         1.2
# 119009         4.4        36.5        32.2        85.9         0.9
# 119010         5.2        42.1        30.4        64.1         0.8
#
#         PLAYER_WEIGHT  DEFENDER_OREB  DEFENDER_DREB  DEFENDER_STL  \
# 119006         101.25            0.1            0.1           0.0
# 119007         101.25            0.0            0.0           0.0
# 119008         119.25            0.0            0.0           0.0
# 119009          92.25            0.9            1.2           0.4
# 119010         110.25            0.2            0.0           0.2
#
#         DEFENDER_BLK  DEFENDER_WEIGHT
# 119006           0.1            98.10
# 119007           0.0           112.50
# 119008           0.0           112.50
# 119009           0.1            88.00
# 119010           0.0            87.75

# %%
data.loc[data['GAME_ID'] == 21400003]
# Out:
#          GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 3115    21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 3116    21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 3117    21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 3123    21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 3128    21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# ...          ...                         ...      ... ..           ...
# 111814  21400003  OCT 28, 2014 - LAL vs. HOU        H  L           -18
# 111815  21400003  OCT 28, 2014 - LAL vs. HOU        H  L           -18
# 112597  21400003  OCT 28, 2014 - LAL vs. HOU        H  L           -18
# 119007  21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
# 119008  21400003    OCT 28, 2014 - HOU @ LAL        A  W            18
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES  TOUCH_TIME  \
# 3115              1       1       8:57        19.0         0         1.2
# 3116              3       2       7:59        13.3         0         0.9
# 3117             10       4       7:58         1.7         2         4.0
# 3123              4       3       5:01        10.1         1         1.4
# 3128              3       1       8:24        22.5         0         1.0
# ...             ...     ...        ...         ...       ...         ...
# 111814            1       1       9:45        17.0         0         1.4
# 111815            7       3      11:20        22.0         0         0.9
# 112597            4       4       3:29         9.2         0         0.7
# 119007            3       3       1:35         3.3         1         2.4
# 119008            2       2      10:10        24.0         0         0.3
#
#         SHOT_DIST  PTS_TYPE SHOT_RESULT     CLOSEST_DEFENDER  \
# 3115         24.1         3        made           JEREMY LIN
# 3116         22.8         3      missed           JEREMY LIN
# 3117          5.9         2      missed           JEREMY LIN
# 3123         19.0         2        made           JEREMY LIN
# 3128         23.5         3        made           JEREMY LIN
# ...           ...       ...         ...                  ...
# 111814       23.3         3        made       TERRENCE JONES
# 111815        1.4         2      missed       TERRENCE JONES
# 112597       17.6         2      missed  KOSTAS PAPANIKOLAOU
# 119007        6.7         2        made        JULIUS RANDLE
# 119008        4.1         2        made        JULIUS RANDLE
#
#         CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  FGM  PTS  \
# 3115                        202391             4.0    1    3
# 3116                        202391             3.0    0    0
# 3117                        202391             2.9    0    0
# 3123                        202391             2.2    1    2
# 3128                        202391             4.0    1    3
# ...                            ...             ...  ...  ...
# 111814                      203093            13.9    1    3
# 111815                      203093             1.5    0    0
# 112597                      203123             5.4    0    0
# 119007                      203944             5.3    1    2
# 119008                      203944             3.2    1    2
#
#                 PLAYER_NAME  PLAYER_ID  PLAYER_HEIGHT  DEFENDER_HEIGHT  \
# 3115           TREVOR ARIZA       2772          200.0            187.5
# 3116           TREVOR ARIZA       2772          200.0            187.5
# 3117           TREVOR ARIZA       2772          200.0            187.5
# 3123            JASON TERRY       1891          188.0            187.5
# 3128           JAMES HARDEN     201935          192.5            187.5
# ...                     ...        ...            ...              ...
# 111814       WESLEY JOHNSON     202325          197.5            202.5
# 111815          JORDAN HILL     201941          205.0            202.5
# 112597         ROBERT SACRE     203135          213.0            200.0
# 119007  KOSTAS PAPANIKOLAOU     203123          200.0            202.5
# 119008        DWIGHT HOWARD       2730          207.5            202.5
#
#         PLAYER_PTS  PLAYER_FG%  PLAYER_3P%  PLAYER_FT%  PLAYER_AST  \
# 3115          12.8        40.2        35.0        85.3         2.5
# 3116          12.8        40.2        35.0        85.3         2.5
# 3117          12.8        40.2        35.0        85.3         2.5
# 3123           7.0        42.2        39.0        81.3         1.9
# 3128          27.4        44.0        37.5        86.8         7.0
# ...            ...         ...         ...         ...         ...
# 111814         9.9        41.4        35.1        80.4         1.6
# 111815        12.0        45.9        27.3        73.8         1.5
# 112597         4.6        41.2         0.0        67.1         0.8
# 119007         4.2        35.0        29.2        72.2         2.0
# 119008        15.8        59.3        50.0        52.8         1.2
#
#         PLAYER_WEIGHT  DEFENDER_OREB  DEFENDER_DREB  DEFENDER_STL  \
# 3115            96.75            0.4            2.3           1.1
# 3116            96.75            0.4            2.3           1.1
# 3117            96.75            0.4            2.3           1.1
# 3123            83.00            0.4            2.3           1.1
# 3128            99.00            0.4            2.3           1.1
# ...               ...            ...            ...           ...
# 111814          96.75            2.4            4.3           0.5
# 111815         105.75            2.4            4.3           0.5
# 112597         122.00            0.9            1.8           0.7
# 119007         101.25            0.0            0.0           0.0
# 119008         119.25            0.0            0.0           0.0
#
#         DEFENDER_BLK  DEFENDER_WEIGHT
# 3115             0.4            90.00
# 3116             0.4            90.00
# 3117             0.4            90.00
# 3123             0.4            90.00
# 3128             0.4            90.00
# ...              ...              ...
# 111814           1.8           113.40
# 111815           1.8           113.40
# 112597           0.3           101.25
# 119007           0.0           112.50
# 119008           0.0           112.50
#
# [106 rows x 34 columns]

# %%
data.columns.values
# Out:
# array(['GAME_ID', 'MATCHUP', 'LOCATION', 'W', 'FINAL_MARGIN',
#        'SHOT_NUMBER', 'PERIOD', 'GAME_CLOCK', 'SHOT_CLOCK', 'DRIBBLES',
#        'TOUCH_TIME', 'SHOT_DIST', 'PTS_TYPE', 'SHOT_RESULT',
#        'CLOSEST_DEFENDER', 'CLOSEST_DEFENDER_PLAYER_ID', 'CLOSE_DEF_DIST',
#        'FGM', 'PTS', 'PLAYER_NAME', 'PLAYER_ID', 'PLAYER_HEIGHT',
#        'DEFENDER_HEIGHT', 'PLAYER_PTS', 'PLAYER_FG%', 'PLAYER_3P%',
#        'PLAYER_FT%', 'PLAYER_AST', 'PLAYER_WEIGHT', 'DEFENDER_OREB',
#        'DEFENDER_DREB', 'DEFENDER_STL', 'DEFENDER_BLK', 'DEFENDER_WEIGHT'],
#       dtype=object)

# %% [markdown]
# ### Manipulating the data

# %%
# separate data into matrix of predictor variables and vector of target variables
names = ['LOCATION', 'SHOT_NUMBER', 'PERIOD', 'GAME_CLOCK', 'SHOT_CLOCK',
         'DRIBBLES', 'SHOT_DIST', 'PTS_TYPE', 'CLOSE_DEF_DIST', 'FGM', 'PTS',
         'PLAYER_HEIGHT','DEFENDER_HEIGHT', 'PLAYER_PTS', 'PLAYER_FG%', 'PLAYER_3P%',
          'PLAYER_FT%','DEFENDER_STL', 'DEFENDER_BLK', 'SHOT_RESULT']

# converting data to usable numerical data
# todo: move this to preprocessing 
def convert_time(time_string):
    time = time_string.split(':')
    return float(time[0])*60 + float(time[1])

# convert game_clock to seconds
data['GAME_CLOCK'] = data['GAME_CLOCK'].apply(lambda x: convert_time(x))

# convert shot_result to either 0 or 1
data['SHOT_RESULT'] = (data['SHOT_RESULT'] == 'made').astype(int)
# convert win to either 0 

# encode categorical data 
data_encoded = pd.get_dummies(data[names])

# split into train and test set with roughly 75-25 split
train, test = train_test_split(data_encoded, test_size=0.25)
Xtrain = train.drop(['SHOT_RESULT'], axis=1)
ytrain = train['SHOT_RESULT']
Xtest = test.drop(['SHOT_RESULT'], axis=1)
ytest = test['SHOT_RESULT']

# %% [markdown]
# ### Setting the baseline
#
# First baseline we consider is to predict every shot within 5 feet of the basket as a make and anything else as a miss.

# %%
yhat = (Xtest['SHOT_DIST'] <= 5).astype(int)
acc = np.mean(yhat == ytest)
print('Accuracy = {0:f}'.format(acc))
# Out:
# Accuracy = 0.606225

# %% [markdown]
# A more complex baseline we can try is to use k-nn algorithm. First, we need to normalize the data so that no one parameter exerts more influence on the result than others.

# %%
# without normalizing data 
neigh = KNeighborsClassifier(n_neighbors=20)
neigh.fit(Xtrain,ytrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')

# %%
yhat_ts = neigh.predict(Xtest)

# %%
acc = np.mean(ytest.values == yhat_ts)
print('Accuracy = {0:f}'.format(acc))
# Out:
# Accuracy = 0.630289

# %%
# with normaliziation 
scaler = StandardScaler()
scaler.fit(Xtrain)
Xtrain_norm = scaler.transform(Xtrain)
scaler.fit(Xtest)
Xtest_norm = scaler.transform(Xtest)

# %%
neigh = KNeighborsClassifier(n_neighbors=20)
neigh.fit(Xtrain_norm,ytrain)
yhat_ts_norm = neigh.predict(Xtest_norm)

# %%
print(type(yhat_ts_norm))
# Out:
# <class 'numpy.ndarray'>

# %%
acc = np.mean(ytest.values == yhat_ts_norm)
print('Accuracy = {0:f}'.format(acc))
# Out:
# Accuracy = 0.999966

# %%
# finding out why the accuracy is so high 
# FGM is not the total field goals made, but whether or not that 
# individual shot was made or not, so we need to drop this 
Xtrain[Xtrain['FGM'] >= 1]
# Out:
#        SHOT_NUMBER  PERIOD  GAME_CLOCK  SHOT_CLOCK  DRIBBLES  SHOT_DIST  \
# 93706           10       3       394.0        10.3         0       24.2
# 72810            1       1        15.0         6.0         1       21.7
# 95259           13       3       480.0        17.0         0       25.3
# 24148            2       1       596.0         8.6         2        6.1
# 98936           11       3       156.0         4.1         4        3.9
# ...            ...     ...         ...         ...       ...        ...
# 6350             4       1       165.0        21.6         0        5.7
# 45914           14       4       648.0        16.6         5       10.3
# 83169           13       4       378.0         7.8         1        8.8
# 38967            2       1       660.0        11.9         0       25.2
# 92703            4       2       313.0        14.6         1       17.9
#
#        PTS_TYPE  CLOSE_DEF_DIST  FGM  PTS  PLAYER_HEIGHT  DEFENDER_HEIGHT  \
# 93706         3            11.2    1    3          205.0            195.0
# 72810         2             2.4    1    2          192.5            202.5
# 95259         3             4.3    1    3          195.0            180.0
# 24148         2             2.1    1    2          202.5            210.0
# 98936         2             1.2    1    2          195.0            202.5
# ...         ...             ...  ...  ...            ...              ...
# 6350          2             4.4    1    2          202.5            197.5
# 45914         2             3.7    1    2          197.5            192.5
# 83169         2             4.7    1    2          210.0            207.5
# 38967         3             4.0    1    3          200.0            200.0
# 92703         2             7.7    1    2          212.5            192.5
#
#        PLAYER_PTS  PLAYER_FG%  PLAYER_3P%  PLAYER_FT%  DEFENDER_STL  \
# 93706        14.3        47.6        37.6        83.6           0.7
# 72810         6.3        41.6        34.2        89.1           1.4
# 95259        14.6        39.6        23.5        69.4           0.7
# 24148        13.5        39.6        37.4        82.0           0.4
# 98936        22.3        37.3        29.3        81.3           0.5
# ...           ...         ...         ...         ...           ...
# 6350         17.1        46.6        36.4        78.8           1.8
# 45914        11.9        41.6        35.4        82.5           0.9
# 83169        19.3        52.3        33.3        75.2           0.4
# 38967        13.9        42.9        34.2        77.5           1.3
# 92703        10.3        66.6         0.0        72.0           0.5
#
#        DEFENDER_BLK  LOCATION_A  LOCATION_H
# 93706           0.2           0           1
# 72810           0.4           1           0
# 95259           0.1           1           0
# 24148           1.2           0           1
# 98936           0.3           0           1
# ...             ...         ...         ...
# 6350            0.6           1           0
# 45914           0.2           1           0
# 83169           1.3           1           0
# 38967           0.2           1           0
# 92703           0.1           0           1
#
# [40623 rows x 20 columns]

# %%
Xtrain_new = Xtrain.drop(['FGM','PTS'], axis=1)
Xtest_new = Xtest.drop(['FGM', 'PTS'], axis=1)
scaler = StandardScaler()
scaler.fit(Xtrain_new)
Xtrain_norm_new = scaler.transform(Xtrain_new)
scaler = StandardScaler()
scaler.fit(Xtest_new)
Xtest_norm_new = scaler.transform(Xtest_new)

# %%
neigh = KNeighborsClassifier(n_neighbors=20)
neigh.fit(Xtrain_norm_new,ytrain)
yhat_ts_norm = neigh.predict(Xtest_norm_new)

# %%
acc = np.mean(ytest.values == yhat_ts_norm)
print('Accuracy = {0:f}'.format(acc))
# Out:
# Accuracy = 0.577858

# %%
Xtest_norm
# Out:
# array([[ 1.17997593,  1.34156716,  1.50316474, ..., -0.86539633,
#         -1.00772655,  1.00772655],
#        [-0.09789587,  1.34156716,  0.48305355, ...,  1.35858441,
#          0.99233269, -0.99233269],
#        [-1.16278903, -1.28838415, -0.50734567, ...,  1.17325268,
#         -1.00772655,  1.00772655],
#        ...,
#        [ 0.3280614 ,  0.46491672,  0.57714147, ...,  0.06126231,
#         -1.00772655,  1.00772655],
#        [ 3.09678362,  1.34156716,  0.1562218 , ..., -0.86539633,
#         -1.00772655,  1.00772655],
#        [-0.52385313, -0.41173371,  1.23575695, ..., -0.86539633,
#         -1.00772655,  1.00772655]])

# %%
# reweight parameters 
# try different number of neighbors
# feature transformation 
# try logistic regression
